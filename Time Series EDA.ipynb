# %%
# !pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
#pdr.get_data_yahoo('TSLA')

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# Download historical data for Tesla (TSLA)
tsla = yf.download('TSLA', start='2020-01-01', end='2025-01-01')

print(tsla.head())
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
tsla.shape
# Out:
# (1258, 5)

# %%
df_tsla=tsla

# %%
df_tsla.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
df_tsla.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2024-12-24  462.279999  462.779999  435.140015  435.899994  59551800
# 2024-12-26  454.130005  465.329987  451.019989  465.160004  76366400
# 2024-12-27  431.660004  450.000000  426.500000  449.519989  82666800
# 2024-12-30  417.410004  427.000000  415.750000  419.399994  64941000
# 2024-12-31  403.839996  427.929993  402.540009  423.790009  76825100

# %%
df_tsla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
# X limit And Y limit

df_tsla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,500],figsize=(12,4), c='green', grid=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df_tsla.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2024-12-17', '2024-12-18', '2024-12-19', '2024-12-20',
#                '2024-12-23', '2024-12-24', '2024-12-26', '2024-12-27',
#                '2024-12-30', '2024-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1258, freq=None)

# %%
df_tsla.loc['2020-01-01':'2021-09-01']
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2020-01-02   28.684000   28.713333   28.114000   28.299999  142981500
# 2020-01-03   29.534000   30.266666   29.128000   29.366667  266677500
# 2020-01-06   30.102667   30.104000   29.333332   29.364668  151995000
# 2020-01-07   31.270666   31.441999   30.224001   30.760000  268231500
# 2020-01-08   32.809334   33.232666   31.215334   31.580000  467164500
# ...                ...         ...         ...         ...        ...
# 2021-08-26  233.720001  238.466660  232.539993  236.103333   39642900
# 2021-08-27  237.306671  238.333328  234.033340  235.000000   41501400
# 2021-08-30  243.636673  243.666672  237.576660  238.240005   55812600
# 2021-08-31  245.240005  246.796661  242.146667  244.333328   62566200
# 2021-09-01  244.696671  247.330002  243.756668  244.693329   39612900
#
# [421 rows x 5 columns]

# %%
index=df_tsla.loc['2020-01-01':'2021-09-01'].index
share_open=df_tsla.loc['2020-01-01':'2021-09-01']['Open']

# %%
share_open
# Out:
# Ticker            TSLA
# Date
# 2020-01-02   28.299999
# 2020-01-03   29.366667
# 2020-01-06   29.364668
# 2020-01-07   30.760000
# 2020-01-08   31.580000
# ...                ...
# 2021-08-26  236.103333
# 2021-08-27  235.000000
# 2021-08-30  238.240005
# 2021-08-31  244.333328
# 2021-09-01  244.693329
#
# [421 rows x 1 columns]

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure, axis=plt.subplots()
plt.tight_layout()
figure.autofmt_xdate() ### Preventing the overlapping
axis.plot(index, share_open)
plt.show()

# %%
### Date Time Data

df_tesla=df_tsla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Date, )        1258 non-null   datetime64[ns]
#  1   (Close, TSLA)   1258 non-null   float64
#  2   (High, TSLA)    1258 non-null   float64
#  3   (Low, TSLA)     1258 non-null   float64
#  4   (Open, TSLA)    1258 non-null   float64
#  5   (Volume, TSLA)  1258 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 59.1 KB

# %%
pd.to_datetime(df_tesla['Date'])
# Out:
# 0      2020-01-02
# 1      2020-01-03
# 2      2020-01-06
# 3      2020-01-07
# 4      2020-01-08
#           ...
# 1253   2024-12-24
# 1254   2024-12-26
# 1255   2024-12-27
# 1256   2024-12-30
# 1257   2024-12-31
# Name: Date, Length: 1258, dtype: datetime64[ns]

# %%
df_tesla.set_index(df_tesla['Date'])
# Out:
# Price            Date       Close        High         Low        Open  \
# Ticker                       TSLA        TSLA        TSLA        TSLA
# Date
# 2020-01-02 2020-01-02   28.684000   28.713333   28.114000   28.299999
# 2020-01-03 2020-01-03   29.534000   30.266666   29.128000   29.366667
# 2020-01-06 2020-01-06   30.102667   30.104000   29.333332   29.364668
# 2020-01-07 2020-01-07   31.270666   31.441999   30.224001   30.760000
# 2020-01-08 2020-01-08   32.809334   33.232666   31.215334   31.580000
# ...               ...         ...         ...         ...         ...
# 2024-12-24 2024-12-24  462.279999  462.779999  435.140015  435.899994
# 2024-12-26 2024-12-26  454.130005  465.329987  451.019989  465.160004
# 2024-12-27 2024-12-27  431.660004  450.000000  426.500000  449.519989
# 2024-12-30 2024-12-30  417.410004  427.000000  415.750000  419.399994
# 2024-12-31 2024-12-31  403.839996  427.929993  402.540009  423.790009
#
# Price          Volume
# Ticker           TSLA
# ...

# %%
## DROP THE DATE COLUMN 
df_tesla=df_tesla.set_index('Date', drop=True)
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2020-01-02   28.684000   28.713333   28.114000   28.299999  142981500
# 2020-01-03   29.534000   30.266666   29.128000   29.366667  266677500
# 2020-01-06   30.102667   30.104000   29.333332   29.364668  151995000
# 2020-01-07   31.270666   31.441999   30.224001   30.760000  268231500
# 2020-01-08   32.809334   33.232666   31.215334   31.580000  467164500
# ...                ...         ...         ...         ...        ...
# 2024-12-24  462.279999  462.779999  435.140015  435.899994   59551800
# 2024-12-26  454.130005  465.329987  451.019989  465.160004   76366400
# 2024-12-27  431.660004  450.000000  426.500000  449.519989   82666800
# 2024-12-30  417.410004  427.000000  415.750000  419.399994   64941000
# 2024-12-31  403.839996  427.929993  402.540009  423.790009   76825100
#
# [1258 rows x 5 columns]

# %%
df_tesla.head()
# Out:
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  TSLA       TSLA       TSLA       TSLA       TSLA
# 0      2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 1      2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2      2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 3      2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 4      2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
from datetime import datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 4, 8, 17, 45, 9, 189112)

# %%
def add_num(num1, num2):
    return num1+num2

# %%
start_time=datetime.now()
num1=20
num2=40
for i in [1,2,3,4,5]:
    add_num(num1, num2)
end_time=datetime.now()

# %%
print(end_time-start_time)
# Out:
# 0:00:00

# %%
date=datetime(2021,11,21)

# %%
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
## Time Resampling
df_tesla.head()
# Out:
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  TSLA       TSLA       TSLA       TSLA       TSLA
# 0      2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 1      2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2      2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 3      2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 4      2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
#df_tesla.resample(rule='A').min()

# %%
### Roling 

df_tesla['High'].rolling(10).mean().head(20)
# Out:
# Ticker       TSLA
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9       32.673333
# 10      33.231733
# 11      33.642866
# 12      34.289666
# 13      35.108799
# 14      35.665533
# 15      36.165932
# 16      36.695932
# 17      37.037132
# 18      37.319732
# 19      38.073332

# %%
df_tesla.head()
# Out:
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  TSLA       TSLA       TSLA       TSLA       TSLA
# 0      2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 1      2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2      2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 3      2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 4      2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
df_tesla['open:30 days rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head(31)
# Out:
# Price        Date      Close       High        Low       Open     Volume  \
# Ticker                  TSLA       TSLA       TSLA       TSLA       TSLA
# 0      2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 1      2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2      2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 3      2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 4      2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500
# 5      2020-01-09  32.089333  33.253334  31.524668  33.139999  426606000
# 6      2020-01-10  31.876667  32.329334  31.580000  32.119331  194392500
# 7      2020-01-13  34.990665  35.042000  32.799999  32.900002  397764000
# 8      2020-01-14  35.861332  36.493999  34.993332  36.284000  434943000
# 9      2020-01-15  34.566666  35.855999  34.452667  35.317333  260532000
# 10     2020-01-16  34.232666  34.297333  32.811333  32.916668  326050500
# ...

# %%
df_tesla[['Open','open:30 days rolling']].plot(figsize=(12,5))
plt.show()
